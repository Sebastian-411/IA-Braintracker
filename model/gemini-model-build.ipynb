# %% [markdown]
# ### Install & import

# %%
! pip install -U -q google-generativeai

# %%
# Install the client library and import necessary modules.
import google.generativeai as genai

import base64
import io
import json
import mimetypes
import pathlib
import pprint
import requests

import PIL.Image
import IPython.display
from IPython.display import Markdown

# %% [markdown]
# ## Set the API key

# %% [markdown]
# Add your API_KEY to the secrets manager in the left panel "🔑".

# %%
import os

resources_dir = "resource"

api_key = os.path.join(resources_dir, "api_key.txt")

if os.path.exists(api_key):
    with open(api_key, "r") as f:
        api_key = f.read().strip()
    print("Contenido de api_key.txt:", api_key)
else:
    print("El archivo api_key.txt no existe en la carpeta de recursos.")
# Out:
# Contenido de api_key.txt: AIzaSyCmFdh6cWQqgQY9oIWR0VLiPsq-WkcLRzw

# %%
API_KEY= api_key

# %%
genai.configure(api_key=API_KEY)

# %% [markdown]
# ### Parse the arguments

# %%
import os

resources_dir = "resource"

token_file = os.path.join(resources_dir, "token.txt")

if os.path.exists(token_file):
    with open(token_file, "r") as f:
        token = f.read().strip()
    print("Contenido de token.txt:", token)
else:
    print("El archivo token.txt no existe en la carpeta de recursos.")
# Out:
# Contenido de token.txt: ...

# %% [markdown]
# ### Call the API

# %%
# Call the model and print the response.
content = "Resultado del MRI: El modelo predictivo observa la probabilidad de que haya un tumor.\n El paciente se queja de dolores de cabeza recurrentes, mareos y visión borrosa. Ha experimentado estos síntomas durante los últimos seis meses. No hay antecedentes de trauma craneal. No se observaron anomalías neurológicas en el examen físico."

gemini = genai.GenerativeModel(model_name=model)

response = gemini.generate_content(
    content,
    generation_config=generation_config,
    safety_settings=safety_settings,
    stream=False)

# %%
if generation_config.get('candidate_count', 1) == 1:
  display(Markdown(response.text))
else:
  print(response.candidates)
# Out:
# ## Interpretación de los Resultados y Recomendaciones:
#
# **Hallazgos:** El resultado del MRI indica la posibilidad de un tumor, pero no lo confirma. Esto, combinado con los síntomas del paciente (dolores de cabeza recurrentes, mareos y visión borrosa durante 6 meses), sugiere la necesidad de una investigación más profunda.
#
# **Recomendaciones:**
#
# * **Evaluación Neurológica Adicional:**
#     * Un examen neurológico más exhaustivo para evaluar funciones como el equilibrio, la coordinación, los reflejos y la función sensorial.
#     * Pruebas neuropsicológicas para evaluar la memoria, la atención y el lenguaje.
# * **Estudios de Imagen Adicionales:**
#     * Una resonancia magnética con contraste para obtener imágenes más detalladas del cerebro y posibles tumores.
#     * Una tomografía por emisión de positrones (PET) o una tomografía computarizada por emisión de fotón único (SPECT) para evaluar la actividad metabólica del cerebro y detectar posibles tumores.
# ...

# %%
response.candidates
# Out:
# [index: 0
# content {
#   parts {
# ...

# %%
response.prompt_feedback

# %%
response = gemini.generate_content("Resultado del MRI: El modelo predictivo observa la probabilidad de que haya un tumor.\n El paciente se queja de dolores de cabeza recurrentes, mareos y visión borrosa. Ha experimentado estos síntomas durante los últimos seis meses. No hay antecedentes de trauma craneal. No se observaron anomalías neurológicas en el examen físico.")

print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
# ...

# %%
response = gemini.generate_content(
    "Resultado del MRI: El modelo predictivo observa la probabilidad de que haya un tumor.\n El paciente se queja de dolores de cabeza recurrentes, mareos y visión borrosa. Ha experimentado estos síntomas durante los últimos seis meses. No hay antecedentes de trauma craneal. No se observaron anomalías neurológicas en el examen físico."
    ,
    generation_config=generation_config,
    safety_settings=safety_settings,
    stream=False)

result = response.candidates[0].content.parts[0].text


display(Markdown(result))
# Out:
# ## Evaluación de la Situación del Paciente:
#
# **Información proporcionada:**
#
# * **Resultado del MRI:** El modelo predictivo sugiere la probabilidad de un tumor.
# * **Síntomas:** Dolores de cabeza recurrentes, mareos y visión borrosa durante los últimos seis meses.
# * **Antecedentes:** Sin trauma craneal.
# * **Examen físico:** Sin anomalías neurológicas.
#
# **Recomendaciones:**
#
# 1. **Evaluación adicional del MRI:**
#     * Es crucial determinar la localización, tamaño y tipo de tumor (si está presente).
#     * Un neurorradiólogo debe analizar detalladamente las imágenes para evaluar la posibilidad de un tumor, su naturaleza (benigno o maligno) y su relación con las estructuras cerebrales adyacentes.
# 2. **Pruebas adicionales:**
#     * **Angiografía cerebral:** Para descartar aneurismas u otras anomalías vasculares.
#     * **Punción lumbar:** En algunos casos, puede ser necesaria para analizar el líquido cefalorraquídeo y descartar infecciones o inflamación.
# ...

# %%
# Out:
# <method-wrapper '__getattribute__' of GenerativeModel object at 0x000001D1FCDF7BF0>

# %%
import joblib

# Guardar el modelo en un archivo .pkl usando joblib
joblib.dump(gemini.__str__, 'modelo_genai.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       1 import joblib
#       3 # Guardar el modelo en un archivo .pkl usando joblib
# ----> 4 joblib.dump(gemini.__getattribute__, 'modelo_genai.pkl')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\numpy_pickle.py:553, in dump(value, filename, compress, protocol, cache_size)
#     551 elif is_filename:
#     552     with open(filename, 'wb') as f:
# --> 553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#     555     NumpyPickler(filename, protocol=protocol).dump(value)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\pickle.py:481, in _Pickler.dump(self, obj)
#     479 if self.proto >= 4:
#     480     self.framer.start_framing()
# ...
